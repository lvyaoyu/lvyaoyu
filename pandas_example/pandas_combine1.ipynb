# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def make_df(index,columns):
    data = {col:[col+str(idx) for idx in index] for col in columns}
    df = DataFrame(data=data,index=index)    
    return df

df = make_df(index=[1,2,3,4],columns='ABCD')
df
# Out:
#     A   B   C   D
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4

# %% [markdown]
# ### 使用pd.concat()级联

# %% [markdown]
# pandas使用pd.concat函数，与np.concatenate函数类似，只是多了一些参数：
# + objs
# + axis
# + join='outer'
# + join_axes=None
# + ignore_index=False
# + key=[value1,value2...]

# %% [markdown]
# ### 简单级联

# %%
df1 = make_df(index=[1,2,3,4],columns='ABCD')
df2 = make_df(index=[1,2,3,4],columns='ABCD')

# %%
# axis=0 默认增加行数
pd.concat(objs=[df1,df2]) # 索引重复
# Out:
#     A   B   C   D
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4

# %%
# ignore_index=True 丢弃原来的索引，重新分配索引
pd.concat(objs=[df1,df2],ignore_index=True)
# Out:
#     A   B   C   D
# 0  A1  B1  C1  D1
# 1  A2  B2  C2  D2
# 2  A3  B3  C3  D3
# 3  A4  B4  C4  D4
# 4  A1  B1  C1  D1
# 5  A2  B2  C2  D2
# 6  A3  B3  C3  D3
# 7  A4  B4  C4  D4

# %%
# keys=['df1','df2'] 使用多层索引区分
pd.concat(objs=[df1,df2],keys=['df1','df2'])
# Out:
#         A   B   C   D
# df1 1  A1  B1  C1  D1
#     2  A2  B2  C2  D2
#     3  A3  B3  C3  D3
#     4  A4  B4  C4  D4
# df2 1  A1  B1  C1  D1
#     2  A2  B2  C2  D2
#     3  A3  B3  C3  D3
#     4  A4  B4  C4  D4

# %%
pd.concat(objs=[df1,df2],axis=1)
# Out:
#     A   B   C   D   A   B   C   D
# 1  A1  B1  C1  D1  A1  B1  C1  D1
# 2  A2  B2  C2  D2  A2  B2  C2  D2
# 3  A3  B3  C3  D3  A3  B3  C3  D3
# 4  A4  B4  C4  D4  A4  B4  C4  D4

# %%
pd.concat(objs=[df1,df2],axis=1,ignore_index=True)
# Out:
#     0   1   2   3   4   5   6   7
# 1  A1  B1  C1  D1  A1  B1  C1  D1
# 2  A2  B2  C2  D2  A2  B2  C2  D2
# 3  A3  B3  C3  D3  A3  B3  C3  D3
# 4  A4  B4  C4  D4  A4  B4  C4  D4

# %%
pd.concat(objs=[df1,df2],axis=1,keys=['df1','df2'])
# Out:
#   df1             df2
#     A   B   C   D   A   B   C   D
# 1  A1  B1  C1  D1  A1  B1  C1  D1
# 2  A2  B2  C2  D2  A2  B2  C2  D2
# 3  A3  B3  C3  D3  A3  B3  C3  D3
# 4  A4  B4  C4  D4  A4  B4  C4  D4

# %% [markdown]
# =========================================
#
# 练习13：
# 1. 想一想级联的应用场景
# 2. 使用昨日的额知识，建立一个期中考试张三李四成绩表ddd
# 3. 假设新增考试学科‘计算机’，如何实现
# 4. 新增王老五同学，如何实现
#
# =========================================

# %%
# 2
data = np.random.randint(1,150,size=(4,4))
index = ['张三','李四','王五','赵六']
columns = ['语文','数学','英语','体育']
ddd = DataFrame(data,index,columns)
ddd
# Out:
#      语文   数学   英语   体育
# 张三  117  127   74  128
# 李四   86  123   76   98
# 王五   56   25   48  124
# 赵六  106   13  147   69

# %%
# 3
data = np.random.randint(1,150,size=(4,1))
index = ['张三','李四','王五','赵六']
columns = ['计算机']
computer = DataFrame(data,index,columns)
pd.concat(objs=[ddd,computer],axis=1)
# Out:
#      语文   数学   英语   体育  计算机
# 张三  117  127   74  128   19
# 李四   86  123   76   98   74
# 王五   56   25   48  124  110
# 赵六  106   13  147   69  137

# %%
data = np.random.randint(1,150,size=(1,4))
index = ['王老五']
columns = ['语文','数学','英语','体育']
wlw = DataFrame(data,index,columns)
pd.concat(objs=[ddd,wlw],axis=0)
# Out:
#       语文   数学   英语   体育
# 张三   117  127   74  128
# 李四    86  123   76   98
# 王五    56   25   48  124
# 赵六   106   13  147   69
# 王老五   93   68   21   91

# %% [markdown]
# ### 不匹配级联

# %%
df1 = make_df(index=[1,2,3,4],columns='ABCD')
df2 = make_df(index=[2,3,4,5],columns='BCDE')
display(df1,df2)
# Out:
#     A   B   C   D
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
#     B   C   D   E
# 2  B2  C2  D2  E2
# 3  B3  C3  D3  E3
# 4  B4  C4  D4  E4
# 5  B5  C5  D5  E5

# %%
pd.concat(objs=[df1,df2])
# Out:
#      A   B   C   D    E
# 1   A1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 4   A4  B4  C4  D4  NaN
# 2  NaN  B2  C2  D2   E2
# 3  NaN  B3  C3  D3   E3
# 4  NaN  B4  C4  D4   E4
# 5  NaN  B5  C5  D5   E5

# %%
pd.concat(objs=[df1,df2],axis=1)
# Out:
#      A    B    C    D    B    C    D    E
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   C2   D2   E2
# 3   A3   B3   C3   D3   B3   C3   D3   E3
# 4   A4   B4   C4   D4   B4   C4   D4   E4
# 5  NaN  NaN  NaN  NaN   B5   C5   D5   E5

# %% [markdown]
# 有3种连接方式
# + 外连接：全部匹配，为空的补NaN（默认方式）

# %%
pd.concat(objs=[df1,df2],axis=0,join='outer')
# Out:
#      A   B   C   D    E
# 1   A1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 3   A3  B3  C3  D3  NaN
# 4   A4  B4  C4  D4  NaN
# 2  NaN  B2  C2  D2   E2
# 3  NaN  B3  C3  D3   E3
# 4  NaN  B4  C4  D4   E4
# 5  NaN  B5  C5  D5   E5

# %% [markdown]
# + 内连接：inner(匹配到的显示出来)

# %%
pd.concat(objs=[df1,df2],axis=0,join='inner')
# Out:
#     B   C   D
# 1  B1  C1  D1
# 2  B2  C2  D2
# 3  B3  C3  D3
# 4  B4  C4  D4
# 2  B2  C2  D2
# 3  B3  C3  D3
# 4  B4  C4  D4
# 5  B5  C5  D5

# %% [markdown]
# + 指定连接轴

# %%
pd.concat(objs=[df1,df2],axis=0,join='inner',ignore_index=True).reindex(index=df1.index)
# Out:
#     B   C   D
# 1  B2  C2  D2
# 2  B3  C3  D3
# 3  B4  C4  D4
# 4  B2  C2  D2

# %% [markdown]
# =========================================
#
# 练习14：
# 1. 假设【期末】考试ddd2的成绩表没有张三的，只有李四、王老五，赵小六的，使用多种方法级联ddd
#
# =========================================

# %%
# 1
ddd
# Out:
#      语文   数学   英语   体育
# 张三  117  127   74  128
# 李四   86  123   76   98
# 王五   56   25   48  124
# 赵六  106   13  147   69

# %%
data = np.random.randint(1,150,size=(3,4))
index = ['李四','王老五','赵小六']
columns = ['语文','数学','英语','体育']
ddd2 = DataFrame(data,index,columns)
ddd2
# Out:
#      语文  数学   英语  体育
# 李四   80  33  123   8
# 王老五  48  22   85  73
# 赵小六  50  29   87  55

# %%
pd.concat(objs=[ddd,ddd2],keys=['期中','期末'])
# Out:
#          语文   数学   英语   体育
# 期中 张三   117  127   74  128
#    李四    86  123   76   98
#    王五    56   25   48  124
#    赵六   106   13  147   69
# 期末 李四    80   33  123    8
#    王老五   48   22   85   73
#    赵小六   50   29   87   55

# %%
pd.concat(objs=[ddd,ddd2],axis=1,keys=['期中','期末'])
# Out:
#         期中                         期末
#         语文     数学     英语     体育    语文    数学     英语    体育
# 张三   117.0  127.0   74.0  128.0   NaN   NaN    NaN   NaN
# 李四    86.0  123.0   76.0   98.0  80.0  33.0  123.0   8.0
# 王五    56.0   25.0   48.0  124.0   NaN   NaN    NaN   NaN
# 赵六   106.0   13.0  147.0   69.0   NaN   NaN    NaN   NaN
# 王老五    NaN    NaN    NaN    NaN  48.0  22.0   85.0  73.0
# 赵小六    NaN    NaN    NaN    NaN  50.0  29.0   87.0  55.0

# %%
pd.concat(objs=[ddd,ddd2],axis=1,keys=['期中','期末'],sort=True).reindex(index=ddd2.index)
# Out:
#        期中                       期末
#        语文     数学    英语    体育    语文    数学     英语    体育
# 李四   86.0  123.0  76.0  98.0  80.0  33.0  123.0   8.0
# 王老五   NaN    NaN   NaN   NaN  48.0  22.0   85.0  73.0
# 赵小六   NaN    NaN   NaN   NaN  50.0  29.0   87.0  55.0

# %% [markdown]
# ### 使用append()函数添加
#
# 由于在后面级联的使用非常普遍，因此有一个函数append专门用来在后面添加
#
# 【注意】：concat是pd的方法，append是DataFrame对象的方法

# %%
ddd.append(ddd2)
# Out:
#       语文   数学   英语   体育
# 张三   117  127   74  128
# 李四    86  123   76   98
# 王五    56   25   48  124
# 赵六   106   13  147   69
# 李四    80   33  123    8
# 王老五   48   22   85   73
# 赵小六   50   29   87   55

# %%
# verify_integrity=True 表示有重复的就会报错
# ddd.append(ddd2,verify_integrity=True)

# %%
# ignore_index=True 表示有重复的就会生成索引
ddd.append(ddd2,ignore_index=True)
# Out:
#     语文   数学   英语   体育
# 0  117  127   74  128
# 1   86  123   76   98
# 2   56   25   48  124
# 3  106   13  147   69
# 4   80   33  123    8
# 5   48   22   85   73
# 6   50   29   87   55

# %% [markdown]
# ### 归纳总结：
# pandas的级联：
# + pd.concat(objs=[df1,df2,df3,...])
# + ignore_index(重新生成索引)
# + keys (生成二级索引)
# + join (外连接：outner,内连接：inner)

# %% [markdown]
# ### 2.使用pd.merge()合并
# merge与concat的区别在于，merge需要依据某一共同的行或列来进行合并
# 使用pd.merge()合并时，会自动根据两者相同的column名称那一列，作为key来进行合并
# 【注意】：每一列元素顺序不要求一致

# %% [markdown]
# #### (1).一对一合并

# %%
data={'name':['张三','李四','Chales'],'id':[1,2,3],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'sex':['男','男','女'],'id':[2,3,4],'group':['sale','search','service']}
df2 = DataFrame(data=data)
display(df1,df2)
# Out:
#      name  id  age
# 0      张三   1   22
# 1      李四   2   25
# 2  Chales   3   28
#   sex  id    group
# 0   男   2     sale
# 1   男   3   search
# 2   女   4  service

# %%
pd.merge(left=df1,right=df2)
# Out:
#      name  id  age sex   group
# 0      李四   2   25   男    sale
# 1  Chales   3   28   男  search

# %%
df1.merge(df2)
# Out:
#      name  id  age sex   group
# 0      李四   2   25   男    sale
# 1  Chales   3   28   男  search

# %% [markdown]
# #### (2).多对一合并

# %%
data={'name':['张三','李四','Chales'],'id':[1,2,2],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'sex':['男','男','女'],'id':[2,3,4],'group':['sale','search','service']}
df2 = DataFrame(data=data)
display(df1,df2)
# Out:
#      name  id  age
# 0      张三   1   22
# 1      李四   2   25
# 2  Chales   2   28
#   sex  id    group
# 0   男   2     sale
# 1   男   3   search
# 2   女   4  service

# %%
df1.merge(df2)
# Out:
#      name  id  age sex group
# 0      李四   2   25   男  sale
# 1  Chales   2   28   男  sale

# %% [markdown]
# #### (3).多对多合并

# %%
data={'name':['张三','李四','张三'],'salary':[10000,20000,25000],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'sex':['男','男','女'],'name':['张三','张三','帆帆'],'group':['sale','search','service']}
df2 = DataFrame(data=data)
display(df1,df2)
# Out:
#   name  salary  age
# 0   张三   10000   22
# 1   李四   20000   25
# 2   张三   25000   28
#   sex name    group
# 0   男   张三     sale
# 1   男   张三   search
# 2   女   帆帆  service

# %%
df1.merge(df2)
# Out:
#   name  salary  age sex   group
# 0   张三   10000   22   男    sale
# 1   张三   10000   22   男  search
# 2   张三   25000   28   男    sale
# 3   张三   25000   28   男  search

# %% [markdown]
# #### (4).key的规划范

# %%
data={'name':['张三','李四','张三'],'salary':[10000,20000,25000],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'age':[25,30,28],'name':['张三','张三','帆帆'],'group':['sale','search','service']}
df2 = DataFrame(data=data)
display(df1,df2)
# Out:
#   name  salary  age
# 0   张三   10000   22
# 1   李四   20000   25
# 2   张三   25000   28
#    age name    group
# 0   25   张三     sale
# 1   30   张三   search
# 2   28   帆帆  service

# %%
# 因为age和name列都有相同的元素，merge不知道该合并哪一列了
df1.merge(df2)
# Out:
# Empty DataFrame
# Columns: [name, salary, age, group]
# Index: []

# %%
# 当有多个列相同时，需要使用on来指定具体使用哪一列合并
df1.merge(df2,on='name')
# Out:
#   name  salary  age_x  age_y   group
# 0   张三   10000     22     25    sale
# 1   张三   10000     22     30  search
# 2   张三   25000     28     25    sale
# 3   张三   25000     28     30  search

# %% [markdown]
# 当列名不同，但值相同时，使用left_on和right_on

# %%
data={'name':['张三','李四','张三'],'salary':[10000,20000,25000],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'年龄':[25,30,28],'姓名':['张三','张三','帆帆'],'group':['sale','search','service']}
df2 = DataFrame(data=data)
display(df1,df2)
# Out:
#   name  salary  age
# 0   张三   10000   22
# 1   李四   20000   25
# 2   张三   25000   28
#    年龄  姓名    group
# 0  25  张三     sale
# 1  30  张三   search
# 2  28  帆帆  service

# %%
df1.merge(df2,left_on='name',right_on='姓名')
# Out:
#   name  salary  age  年龄  姓名   group
# 0   张三   10000   22  25  张三    sale
# 1   张三   10000   22  30  张三  search
# 2   张三   25000   28  25  张三    sale
# 3   张三   25000   28  30  张三  search

# %% [markdown]
# 当左边列值的和右边的index值相同的时候，使用right_index=True

# %%
data={'name':['张三','李四','张三'],'salary':[10000,20000,25000],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'年龄':[25,30,28],'姓名':['张三','张三','帆帆'],'group':['sale','search','service']}
df2 = DataFrame(data=data,index=[22,25,28])
display(df1,df2)
# Out:
#   name  salary  age
# 0   张三   10000   22
# 1   李四   20000   25
# 2   张三   25000   28
#     年龄  姓名    group
# 22  25  张三     sale
# 25  30  张三   search
# 28  28  帆帆  service

# %%
df1.merge(df2,left_on='age',right_index=True)
# Out:
#   name  salary  age  年龄  姓名    group
# 0   张三   10000   22  25  张三     sale
# 1   李四   20000   25  30  张三   search
# 2   张三   25000   28  28  帆帆  service

# %% [markdown]
# ===============================================
#
# 练习16：
# 1. 假设有两份成绩单，除了ddd是张三李四王老五之外，还有ddd2是张三和赵小六的成绩单，如何合并？
# 2. 如果ddd中张三的名字被打错了，成了张十三，该怎么办？
# 3. 自行练习多对一，多对多的情况
# 4. 自学left_index,right_index
#
# ===============================================

# %%
# 1
data = [[112,55,40],[55,50,81],[125,115,44]]
index = ['张三','李四','王老五']
columns = ['语文','数学','英语']
ddd = DataFrame(data,index,columns)
ddd
# Out:
#       语文   数学  英语
# 张三   112   55  40
# 李四    55   50  81
# 王老五  125  115  44

# %%
data = [[112,55,40],[130,68,98]]
index = ['张三','赵小六']
columns = ['语文','数学','英语']
ddd2 = DataFrame(data,index,columns)
ddd2
# Out:
#       语文  数学  英语
# 张三   112  55  40
# 赵小六  130  68  98

# %%
# ddd.merge(ddd2,how='outer')
ddd.join(ddd2,how='outer',lsuffix='ddd')
# Out:
#      语文ddd  数学ddd  英语ddd     语文    数学    英语
# 张三   112.0   55.0   40.0  112.0  55.0  40.0
# 李四    55.0   50.0   81.0    NaN   NaN   NaN
# 王老五  125.0  115.0   44.0    NaN   NaN   NaN
# 赵小六    NaN    NaN    NaN  130.0  68.0  98.0

# %% [markdown]
# #### 外合并
# 默认内合并

# %%
data={'name':['张三','李四','张三'],'salary':[10000,20000,25000],'age':[22,25,28]}
df1 = DataFrame(data=data)
data={'年龄':[25,30,28],'姓名':['张三','张三','帆帆'],'group':['sale','search','service']}
df2 = DataFrame(data=data,index=[22,25,28])
display(df1,df2)
# Out:
#   name  salary  age
# 0   张三   10000   22
# 1   李四   20000   25
# 2   张三   25000   28
#     年龄  姓名    group
# 22  25  张三     sale
# 25  30  张三   search
# 28  28  帆帆  service

# %%
df1.merge(df2,left_on='name',right_on='姓名',how='outer')
# Out:
#   name   salary   age    年龄   姓名    group
# 0   张三  10000.0  22.0  25.0   张三     sale
# 1   张三  10000.0  22.0  30.0   张三   search
# 2   张三  25000.0  28.0  25.0   张三     sale
# 3   张三  25000.0  28.0  30.0   张三   search
# 4   李四  20000.0  25.0   NaN  NaN      NaN
# 5  NaN      NaN   NaN  28.0   帆帆  service

# %% [markdown]
# pd.merge()
# + left,合并的左表
# + right,合并的右表
# + how='inner',左右内外合并
# + on=None,指定合并的列
# + left_on=None,指定左表合并的列
# + right_on=None,指定右表合并的列
# + left_index=False,跟左表的索引值匹配合并
# + right_index=False,跟右表的索引值匹配合并
# + sort=False,
# + suffixes=('_x', '_y'),指定相同列名后缀

# %% [markdown]
# ## 案例分析：每个各州人口数据分析

# %% [markdown]
# unique() 去重函数
# 只能用于一维

# %%
s = Series(['Tom','Lucy','Tom','Kangkang','Lucy'])
s
# Out:
# 0         Tom
# 1        Lucy
# 2         Tom
# 3    Kangkang
# 4        Lucy
# dtype: object

# %%
s.unique()
# Out:
# array(['Tom', 'Lucy', 'Kangkang'], dtype=object)

# %% [markdown]
# query条件查询函数

# %%
df = DataFrame(data={'name':['Tom','Lucy','Tom','Kangkang','Lucy'],
                     'age':[20,25,27,26,12]})
df
# Out:
#        name  age
# 0       Tom   20
# 1      Lucy   25
# 2       Tom   27
# 3  Kangkang   26
# 4      Lucy   12

# %%
# 查询名字是Lucy，并且年龄大于22
df.query("name=='Lucy'&age>13")
# Out:
#    name  age
# 1  Lucy   25
