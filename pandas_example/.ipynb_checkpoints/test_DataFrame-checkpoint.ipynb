# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\EDZ\Desktop\汉星\excel-pdf\016.xlsx',keep_default_na=False)
df['数量'] = df['数量'].astype('int64')
df['单价'] = df['单价'].astype('int64')
df['金额'] = df['金额'].astype('int64')
df['已核销'] = df['已核销'].astype('int64')
df['未核销'] = df['未核销'].astype('int64')
df['运单号'] = [i.split('-')[-1] for i in df['运单号']]
df.index = range(2,len(df.index)+2)
df.drop(index=list(df[df['费用'] == '主单费'].index), inplace=True)
del_list = []
for i in range(0,len(df.index)-1):
    for j in range(i+1,len(df.index)):
        if df.loc[df.index[i],'订单号']==df.loc[df.index[j],'订单号'] and df.loc[df.index[i],'运单号']==df.loc[df.index[j],'运单号'] and df.loc[df.index[i],'航程']==df.loc[df.index[j],'航程'] and df.loc[df.index[i],'数量']==df.loc[df.index[j],'数量'] and df.loc[df.index[i],'费用']==df.loc[df.index[j],'费用']:
            print(df.index[i],df.index[j])
            df.loc[df.index[i],'单价'] += df.loc[df.index[j],'单价']
            df.loc[df.index[i],'金额'] += df.loc[df.index[j],'金额']
            df.loc[df.index[i],'已核销'] += df.loc[df.index[j],'已核销']
            df.loc[df.index[i],'未核销'] += df.loc[df.index[j],'未核销']
            df.loc[df.index[i],'附加说明'] = df.loc[df.index[i],'附加说明'] if df.loc[df.index[i],'附加说明']!='' else df.loc[df.index[j],'附加说明']
            del_list.append(df.index[j])

df.drop(index=del_list,inplace=True)
df.to_excel(r'C:\Users\EDZ\Desktop\汉星\excel-pdf\副本-016.xlsx')
# Out:
# 9 10
# 21 22
# 31 32
# 38 39
# 69 71
# 78 79
# 91 92
# 95 96
# 106 107
# 109 110

# %%
df = pd.read_excel(r'C:\Users\EDZ\Desktop\汉星\制单费\202012制单费-远航原表.xlsx')
df
# Out:
#               总单号          分单号             运抵报告发送时间 是否已入海关库   放行件数    放行重量  \
# 0    016-54483424         2170  2020-12-19 09:55:17   已入海关库   30.0   525.0
# 1    016-54483435         1948  2020-12-19 09:55:22   已入海关库   42.0   735.0
# 2    016-54483446         2239  2020-12-20 14:45:29   已入海关库  110.0  1870.0
# 3    016-55952002         2427  2020-12-12 16:13:53   已入海关库  250.0  4375.0
# 4    016-55952013         2246  2020-12-13 10:33:55   已入海关库   90.0  1575.0
# ..            ...          ...                  ...     ...    ...     ...
# 114  016-62380581         8456  2020-12-11 11:28:11   已入海关库   75.0  1275.0
# 115  016-62380592         9952  2020-12-11 11:28:22   已入海关库   84.0  1428.0
# 116  016-62508714  SSHA5296643  2020-12-26 13:33:21   已入海关库    6.0  2430.0
# 117  016-62508935       052344  2020-12-29 16:11:05   已入海关库    6.0  3618.0
# 118  016-91776565         0217  2020-12-16 14:36:28   已入海关库    1.0   221.0
#
#      运抵件数  运抵重量    操作员账号                            回执内容                 回执时间  \
# 0      30   525  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-19 09:56:50
# 1      42   735  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-19 09:57:15
# 2     110  1870  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-20 14:47:02
# 3     250  4375  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-12 16:15:55
# 4      90  1575  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-13 10:36:03
# ..    ...   ...      ...                             ...                  ...
# 114    75  1275  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-11 11:29:59
# 115    84  1428  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-11 11:30:15
# 116     6  2430  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12-26 13:47:50
# 117     6  3618  PVGLC01  45201 空运出口运抵报告传输成功。比对结果为：运抵正常。  2020-12
# 016-62195906 1
# 016-62195910 1
# 016-62195932 1
# 016-62195954 1
# 016-62195976 1
# 016-62195980 1
# 016-62195991 1
# 016-62196002 1
# 016-62196013 1
# 016-62196024 1
# 016-62196035 1
# 016-62196046 5
# 016-62196050 1
# 016-62196061 1
# 016-62196072 1
# 016-62379343 1
# 016-62379354 1
# 016-62379365 1
# 016-62379590 1
# 016-62380566 1
# 016-62380581 1
# 016-62380592 1
# 016-62508714 1
# 016-62508935 1
# 016-91776565 1

# %%
df.insert(1,'金额',df['counts']*5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-30d2f78da54a> in <module>
# ----> 1 df.insert(1,'金额',df['counts']*5)
#       2 for i in df.index:
#       3     print(df.loc[i,'总单号'],df.loc[i,'金额'])
#
# d:\pycharmprojects\test\venv\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3758         self._ensure_valid_index(value)
#    3759         value = self._sanitize_column(column, value, broadcast=False)
# -> 3760         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3761
#    3762     def assign(self, **kwargs) -> DataFrame:
#
# d:\pycharmprojects\test\venv\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert 金额, already exists

# %%
for i in df.index:
    print(df.loc[i,'总单号'],df.loc[i,'金额'])
# Out:
# 016-54483424 5
# 016-54483435 5
# 016-54483446 5
# 016-55952002 5
# 016-55952013 5
# 016-55952024 5
# 016-55952035 5
# 016-55952046 5
# 016-55952050 5
# 016-55952061 5
# 016-55952072 5
# 016-55952083 5
# 016-55952094 5
# 016-55952105 5
# 016-55952116 5
# 016-55952120 5
# 016-55952131 5
# 016-55952142 5
# 016-55952153 5
# 016-55952164 5
# 016-55952175 5
# 016-55952186 5
# 016-55952190 5
# 016-55952201 5
# 016-55952212 5
# 016-55952223 5
# 016-55952234 5
# 016-55952245 5
# 016-55952256 5
# 016-55952260 5
# 016-55952271 5
# 016-55952282 5
# 016-55952293 5
# 016-55952304 5
# 016-55952315 5
# 016-55952326 5
# 016-55952330 5
# 016-55952341 5
# 016-55952352 5
# 016-55952363 20
# 016-55952374 5
# 016-55952385 5
# 016-55952400 15
# 016-55952411 5
# 016-55952433 5
# 016-55952444 5
# 016-55952455 5
# 016-55952470 5
# 016-55952481 5
# 016-55952492 5
# 016-55952503 5
# 016-55954802 5
# 016-55954846 5
# 016-62195556 5
# 016-62195560 5
# 016-62195571 5
# 016-62195582 5
# 016-62195593 5
# 016-62195604 5
# 016-62195615 5
# 016-62195626 5
# 016-62195630 5
# 016-62195641 5
# 016-62195652 5
# 016-62195663 5
# 016-62195674 5
# 016-62195685 5
# 016-62195696 5
# 016-62195700 5
# 016-62195711 5
# 016-62195766 5
# 016-62195770 5
# 016-62195781 5
# 016-62195792 5
# 016-62195803 5
# 016-62195814 10
# 016-62195825 5
# 016-62195836 5
# 016-62195840 5
# 016-62195851 5
# 016-62195862 5
# 016-62195873 5
# 016-62195884 5
# 016-62195895 5
# 016-62195906 5
# 016-62195910 5
# 016-62195932 5
# 016-62195954 5
# 016-62195976 5
# 016-62195980 5
# 016-62195991 5
# 016-62196002 5
# 016-62196013 5
# 016-62196024 5
# 016-62196035 5
# 016-62196046 25
# 016-62196050 5
# 016-62196061 5
# 016-62196072 5
# 016-62379343 5
# 016-62379354 5
# 016-62379365 5
# 016-62379590 5
# 016-62380566 5
# 016-62380581 5
# 016-62380592 5
# 016-62508714 5
# 016-62508935 5
# 016-91776565 5
